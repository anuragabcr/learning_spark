# %% [markdown]
# ### Into to Databricks Notebook!

# %%
print("hello")

# %%
# %sql
SELECT "Hello SQL";

# %% [markdown]
# ### %fs magic command

# %%
# %fs
ls /

# %%
# %fs
ls /databricks-datasets/

# %% [markdown]
# ### %sh magic command (Driver node only)

# %%
# %sh
ps

# %% [markdown]
# ### %pip magic command

# %%
# %pip 
list

# %%
# %pip install faker

# %% [markdown]
# ### %run magic command (include / import another notebook)

# %%
# %run /Workspace/Users/anuragabcr@gmail.com/learning_spark/dea-course/02-env

# %%
print_dev_info()

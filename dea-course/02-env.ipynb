# %%
env = 'dev'

# %%
import os
import platform

def print_dev_info():
    print(f"Python version: {platform.python_version()}")
    runtime = os.environ.get("DATABRICKS_RUNTIME_VERSION")
    if runtime:
        print(f"Databricks Runtime version: {runtime}")
